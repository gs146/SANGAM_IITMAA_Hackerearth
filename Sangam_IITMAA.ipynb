# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Train.csv")
# df.is_holiday.value_counts()

# %%
df['date_time'] = pd.to_datetime(df['date_time'] ,infer_datetime_format = True)
df = df.set_index(df['date_time'])

# %%
df.head(3)
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00       None                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00       None                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00       None                  113
#
#                      humidity  wind_speed  wind_direction  \
# date_time
# 2012-10-02 09:00:00        89           2             329
# 2012-10-02 10:00:00        67           3             330
# 2012-10-02 11:00:00        66           3             329
#
#                      visibility_in_miles  dew_point  temperature  rain_p_h  \
# date_time
# 2012-10-02 09:00:00                    1          1       288.28       0.0
# 2012-10-02 10:00:00                    1          1       289.36       0.0
# 2012-10-02 11:00:00                    2          2       289.58       0.0
#
#                      snow_p_h  clouds_all weather_type weather_description  \
# date_time
# ...

# %%
df[df.is_holiday == 'Christmas Day']
# Out:
#             date_time     is_holiday  air_pollution_index  humidity  \
# date_time
# 2012-12-25 2012-12-25  Christmas Day                   87        53
# 2013-12-25 2013-12-25  Christmas Day                   14        91
# 2015-12-25 2015-12-25  Christmas Day                   13        94
# 2016-12-26 2016-12-26  Christmas Day                  188        46
# 2016-12-26 2016-12-26  Christmas Day                  287        46
#
#             wind_speed  wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2012-12-25           2             230                    8          8
# 2013-12-25           1             270                    6          6
# 2015-12-25           3              78                    5          5
# 2016-12-26           4             330                    3          3
# 2016-12-26           7             310                    3          3
#
#             temperature  rain_p_h  snow_p_h  clouds_all weather_type  \
# date_time
# ...

# %%
df.is_holiday.value_counts()
# Out:
# None                         33707
# New Years Day                    5
# Thanksgiving Day                 5
# Christmas Day                    5
# Labor Day                        4
# Columbus Day                     4
# Veterans Day                     4
# Washingtons Birthday             4
# Independence Day                 3
# State Fair                       3
# Martin Luther King Jr Day        3
# Memorial Day                     3
# Name: is_holiday, dtype: int64

# %%
df.date_time[df.is_holiday =='Memorial Day']
# Out:
# date_time
# 2013-05-27   2013-05-27
# 2014-05-26   2014-05-26
# 2016-05-30   2016-05-30
# Name: date_time, dtype: datetime64[ns]

# %%
# df.air_pollution_index[df.is_holiday != 'None']

# %%
# plt.plot(df.date_time, df.traffic_volume);

# %%
# plt.figure(figsize=(20,12))
# plt.bar(df.weather_description, df.traffic_volume);

# %%
df.weather_description.unique()
# Out:
# array(['scattered clouds', 'broken clouds', 'overcast clouds',
#        'sky is clear', 'few clouds', 'light rain',
#        'light intensity drizzle', 'mist', 'haze', 'fog',
#        'proximity shower rain', 'drizzle', 'moderate rain',
#        'heavy intensity rain', 'proximity thunderstorm',
#        'thunderstorm with light rain', 'proximity thunderstorm with rain',
#        'heavy snow', 'heavy intensity drizzle', 'snow',
#        'thunderstorm with heavy rain', 'freezing rain', 'shower snow',
#        'light rain and snow', 'light intensity shower rain', 'SQUALLS',
#        'thunderstorm with rain', 'proximity thunderstorm with drizzle',
#        'thunderstorm', 'Sky is Clear', 'very heavy rain',
#        'thunderstorm with light drizzle', 'light snow',
#        'thunderstorm with drizzle', 'smoke', 'shower drizzle',
#        'light shower snow', 'sleet'], dtype=object)

# %%
df.head()
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00       None                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00       None                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00       None                  113
# 2012-10-02 12:00:00 2012-10-02 12:00:00       None                   20
# 2012-10-02 13:00:00 2012-10-02 13:00:00       None                  281
#
#                      humidity  wind_speed  wind_direction  \
# date_time
# 2012-10-02 09:00:00        89           2             329
# 2012-10-02 10:00:00        67           3             330
# 2012-10-02 11:00:00        66           3             329
# 2012-10-02 12:00:00        66           3             329
# 2012-10-02 13:00:00        65           3             329
#
#                      visibility_in_miles  dew_point  temperature  rain_p_h  \
# date_time
# ...

# %%
df.date_time['2014']
# Out:
# date_time
# 2014-01-01 00:00:00   2014-01-01 00:00:00
# 2014-01-01 01:00:00   2014-01-01 01:00:00
# 2014-01-01 02:00:00   2014-01-01 02:00:00
# 2014-01-01 03:00:00   2014-01-01 03:00:00
# 2014-01-01 04:00:00   2014-01-01 04:00:00
# 2014-01-01 05:00:00   2014-01-01 05:00:00
# 2014-01-01 06:00:00   2014-01-01 06:00:00
# 2014-01-01 07:00:00   2014-01-01 07:00:00
# 2014-01-01 08:00:00   2014-01-01 08:00:00
# 2014-01-01 09:00:00   2014-01-01 09:00:00
# 2014-01-01 11:00:00   2014-01-01 11:00:00
# 2014-01-01 12:00:00   2014-01-01 12:00:00
# 2014-01-01 13:00:00   2014-01-01 13:00:00
# 2014-01-01 14:00:00   2014-01-01 14:00:00
# 2014-01-01 15:00:00   2014-01-01 15:00:00
# 2014-01-01 16:00:00   2014-01-01 16:00:00
# 2014-01-01 17:00:00   2014-01-01 17:00:00
# 2014-01-01 18:00:00   2014-01-01 18:00:00
# 2014-01-01 19:00:00   2014-01-01 19:00:00
# 2014-01-01 20:00:00   2014-01-01 20:00:00
# 2014-01-01 22:00:00   2014-01-01 22:00:00
# 2014-01-01 23:00:00   2014-01-01 23:00:00
# ...

# %%
df.is_holiday.value_counts()
# Out:
# None                         33707
# New Years Day                    5
# Thanksgiving Day                 5
# Christmas Day                    5
# Labor Day                        4
# Columbus Day                     4
# Veterans Day                     4
# Washingtons Birthday             4
# Independence Day                 3
# State Fair                       3
# Martin Luther King Jr Day        3
# Memorial Day                     3
# Name: is_holiday, dtype: int64

# %%
df.is_holiday[df.is_holiday == 'New Years Day']
# Out:
# date_time
# 2013-01-01    New Years Day
# 2014-01-01    New Years Day
# 2016-01-01    New Years Day
# 2016-01-01    New Years Day
# 2017-01-02    New Years Day
# Name: is_holiday, dtype: object

# %%
df.traffic_volume[df.is_holiday == 'New Years Day'] #incorrect value at
# Out:
# date_time
# 2013-01-01    1439
# 2014-01-01    1395
# 2016-01-01    1513
# 2016-01-01    1513
# 2017-01-02     798
# Name: traffic_volume, dtype: int64

# %%
df.traffic_volume[df.date_time == '2017-01-01']
# Out:
# date_time
# 2017-01-01    1848
# Name: traffic_volume, dtype: int64

# %%
df.traffic_volume[df.date_time == '2015-01-01']
# Out:
# Series([], Name: traffic_volume, dtype: int64)

# %%
# plt.bar(df.wind_speed, df.traffic_volume)

# %%
# df.wind_speed.value_counts()

# %%
df['2015']
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2015-06-11 20:00:00 2015-06-11 20:00:00       None                  282
# 2015-06-12 18:00:00 2015-06-12 18:00:00       None                   84
# 2015-06-12 20:00:00 2015-06-12 20:00:00       None                   97
# 2015-06-12 21:00:00 2015-06-12 21:00:00       None                   29
# 2015-06-13 21:00:00 2015-06-13 21:00:00       None                   78
# 2015-06-13 23:00:00 2015-06-13 23:00:00       None                  179
# 2015-06-14 20:00:00 2015-06-14 20:00:00       None                  163
# 2015-06-19 18:00:00 2015-06-19 18:00:00       None                  115
# 2015-06-20 18:00:00 2015-06-20 18:00:00       None                  228
# 2015-06-22 00:00:00 2015-06-22 00:00:00       None                  283
# 2015-06-22 18:00:00 2015-06-22 18:00:00       None                  104
# 2015-06-24 04:00:00 2015-06-24 04:00:00       None                  274
# ...

# %%
df.head()
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00       None                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00       None                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00       None                  113
# 2012-10-02 12:00:00 2012-10-02 12:00:00       None                   20
# 2012-10-02 13:00:00 2012-10-02 13:00:00       None                  281
#
#                      humidity  wind_speed  wind_direction  \
# date_time
# 2012-10-02 09:00:00        89           2             329
# 2012-10-02 10:00:00        67           3             330
# 2012-10-02 11:00:00        66           3             329
# 2012-10-02 12:00:00        66           3             329
# 2012-10-02 13:00:00        65           3             329
#
#                      visibility_in_miles  dew_point  temperature  rain_p_h  \
# date_time
# ...

# %%
df.shape
# Out:
# (33750, 15)

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(), annot=True)

# %%
print(df.temperature.max())
print(df.temperature.min())
# Out:
# 308.24
# 0.0

# %% [markdown]
# ### Holidays

# %%
df.index.year.value_counts()
# Out:
# 2016    9306
# 2013    8573
# 2014    4839
# 2015    4373
# 2017    4100
# 2012    2559
# Name: date_time, dtype: int64

# %%
import holidays
off = holidays.US()

# %%
for i in holidays.US(years = 2018).items(): 
    print(i) 
for i in holidays.US(years = 2019).items(): 
    print(i)
# Out:
# (datetime.date(2018, 1, 1), "New Year's Day")
# (datetime.date(2018, 1, 15), 'Martin Luther King, Jr. Day')
# (datetime.date(2018, 2, 19), "Washington's Birthday")
# (datetime.date(2018, 5, 28), 'Memorial Day')
# (datetime.date(2018, 7, 4), 'Independence Day')
# (datetime.date(2018, 9, 3), 'Labor Day')
# (datetime.date(2018, 10, 8), 'Columbus Day')
# (datetime.date(2018, 11, 11), 'Veterans Day')
# (datetime.date(2018, 11, 12), 'Veterans Day (Observed)')
# (datetime.date(2018, 11, 22), 'Thanksgiving')
# (datetime.date(2018, 12, 25), 'Christmas Day')
# (datetime.date(2019, 1, 1), "New Year's Day")
# (datetime.date(2019, 1, 21), 'Martin Luther King, Jr. Day')
# (datetime.date(2019, 2, 18), "Washington's Birthday")
# (datetime.date(2019, 5, 27), 'Memorial Day')
# (datetime.date(2019, 7, 4), 'Independence Day')
# (datetime.date(2019, 9, 2), 'Labor Day')
# (datetime.date(2019, 10, 14), 'Columbus Day')
# (datetime.date(2019, 11, 11), 'Veterans Day')
# ...

# %%
print(off.get(df.index.date[3]))
# df.index.date[0]
# Out:
# None

# %%
print(type(str(off.get(df.index.date[0]))))
# Out:
# <class 'str'>

# %%
# # a = np.array([2012,2013,2014,2015,2016,2017], np.type=int)
# # a=[2012,2013,2014,2015,2016,2017]
# # for j in range(len(a)):    
# #     for i in holidays.US(years = a[j]).items(): 
# from tqdm import tqdm_notebook as tqdm
# chutti = [] 
# for i in tqdm(range(df.shape[0])):
# #     df['chutti'][i] = off.get(df.index.date[i])
#     chutti.append(str(off.get(df.index.date[i])))

# %%
df['chutti'] = chutti

# %%
print(off.get('2018-01-01'))
# Out:
# New Year's Day

# %%
# df.head()
x = df.pop('is_holiday')

# %%
df[df.chutti == 'Independence Day']
# Out:
#                               date_time  air_pollution_index  humidity  \
# date_time
# 2013-07-04 00:00:00 2013-07-04 00:00:00                  236        94
# 2013-07-04 01:00:00 2013-07-04 01:00:00                  122        88
# 2013-07-04 02:00:00 2013-07-04 02:00:00                   39        95
# 2013-07-04 03:00:00 2013-07-04 03:00:00                  285        95
# 2013-07-04 04:00:00 2013-07-04 04:00:00                  223        95
# 2013-07-04 05:00:00 2013-07-04 05:00:00                   96        94
# 2013-07-04 06:00:00 2013-07-04 06:00:00                   31        82
# 2013-07-04 07:00:00 2013-07-04 07:00:00                   30        74
# 2013-07-04 08:00:00 2013-07-04 08:00:00                  185        75
# 2013-07-04 09:00:00 2013-07-04 09:00:00                  270        72
# 2013-07-04 10:00:00 2013-07-04 10:00:00                  177        92
# 2013-07-04 11:00:00 2013-07-04 11:00:00                  230        92
# ...

# %%
# plt.figure(figsize=(20,12))
# xs, ys = zip(*sorted(zip(df.air_pollution_index, df.traffic_volume)))
# plt.plot(xs, ys)

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)

# %%
df.head(2200)
# Out:
#                               date_time  air_pollution_index  humidity  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00                  121        89
# 2012-10-02 10:00:00 2012-10-02 10:00:00                  178        67
# 2012-10-02 11:00:00 2012-10-02 11:00:00                  113        66
# 2012-10-02 12:00:00 2012-10-02 12:00:00                   20        66
# 2012-10-02 13:00:00 2012-10-02 13:00:00                  281        65
# 2012-10-02 14:00:00 2012-10-02 14:00:00                   23        65
# 2012-10-02 15:00:00 2012-10-02 15:00:00                  184        64
# 2012-10-02 16:00:00 2012-10-02 16:00:00                  167        64
# 2012-10-02 17:00:00 2012-10-02 17:00:00                  119        63
# 2012-10-02 18:00:00 2012-10-02 18:00:00                  161        63
# 2012-10-02 19:00:00 2012-10-02 19:00:00                  243        62
# 2012-10-02 20:00:00 2012-10-02 20:00:00                  150        62
# ...

# %%
df.weather_type.value_counts()
# Out:
# Clouds          11213
# Clear            9233
# Mist             4047
# Rain             3940
# Snow             2070
# Drizzle          1204
# Haze              902
# Fog               567
# Thunderstorm      553
# Smoke              17
# Squall              4
# Name: weather_type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.weather_type = le.fit_transform(df.weather_type)

# %%
df.weather_description.value_counts()
x = df.pop('weather_description') #since clouds all is too much related to this feature...clouds all is giving the percentage of weather clear

# %%
df.clouds_all = df.clouds_all/df.clouds_all.max() #scaled the clouds_all feature

# %%
df.describe()
# Out:
#        air_pollution_index      humidity    wind_speed  wind_direction  \
# count         33750.000000  33750.000000  33750.000000    33750.000000
# mean            154.841422     71.209007      3.378193      199.471852
# std              83.735515     16.852248      2.055792       99.841088
# min              10.000000     13.000000      0.000000        0.000000
# 25%              83.000000     60.000000      2.000000      130.000000
# 50%             155.000000     72.000000      3.000000      200.000000
# 75%             228.000000     85.000000      5.000000      290.000000
# max             299.000000    100.000000     16.000000      360.000000
#
#        visibility_in_miles     dew_point   temperature      rain_p_h  \
# count         33750.000000  33750.000000  33750.000000  33750.000000
# mean              4.989748      4.989748    280.069587      0.448739
# std               2.570021      2.570021     13.415256     53.526500
# ...

# %%
df.traffic_volume[df.chutti == 'Veterans Day (Observed)'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f406b566cc51> in <module>
# ----> 1 df.traffic_volume[df.chutti == 'Veterans Day (Observed)'].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'chutti'

# %%
df.chutti.value_counts()

# %%
a = df.chutti.unique()

# %%
a

# %%
l1 = []
l2 = []
for i in tqdm(range(1,len(a))):
    l1.append(df.traffic_volume[df.chutti == a[i]].sum())
    l2.append(a[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-e0db2758aeaa> in <module>
#       1 l1 = []
#       2 l2 = []
# ----> 3 for i in tqdm(range(1,len(a))):
#       4     l1.append(df.traffic_volume[df.chutti == a[i]].sum())
#       5     l2.append(a[i])
#
# NameError: name 'tqdm' is not defined

# %%
l1
# Out:
# []

# %%
# s/df.shape[0]

# %%
plt.figure(figsize=(20,12))
plt.barh(l2,l1)
# Out:
# <BarContainer object of 0 artists>

# %%
# chutti_new = []
# for i in tqdm(range(df.shape[0])):
#     if df['chutti'][i] == 'None':
#         chutti_new.append(0)            
#     elif df['chutti'][i] == 'Christmas Day (Observed)' or df['chutti'][i] =='Independence Day (Observed)' or df['chutti'][i] =='New Year\'s Day (Observed)' or df['chutti'][i] == 'Veterans Day (Observed)' :
#         chutti_new.append(3) 
#     elif df['chutti'][i] == 'Labor Day' or df['chutti'][i] == 'Independence Day'or df['chutti'][i] == 'Memorial Day' or df['chutti'][i] == "New Year's Day" or df['chutti'][i] == 'Christmas Day':
#         chutti_new.append(2) 
#     else:
#         chutti_new.append(1)
        
# df['chutti'] = chutti_new

# %%
df.chutti.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-cb6de9545b12> in <module>
# ----> 1 df.chutti.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'chutti'

# %%
df
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00       None                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00       None                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00       None                  113
# 2012-10-02 12:00:00 2012-10-02 12:00:00       None                   20
# 2012-10-02 13:00:00 2012-10-02 13:00:00       None                  281
# 2012-10-02 14:00:00 2012-10-02 14:00:00       None                   23
# 2012-10-02 15:00:00 2012-10-02 15:00:00       None                  184
# 2012-10-02 16:00:00 2012-10-02 16:00:00       None                  167
# 2012-10-02 17:00:00 2012-10-02 17:00:00       None                  119
# 2012-10-02 18:00:00 2012-10-02 18:00:00       None                  161
# 2012-10-02 19:00:00 2012-10-02 19:00:00       None                  243
# 2012-10-02 20:00:00 2012-10-02 20:00:00       None                  150
# ...

# %%
df.shape
# Out:
# (33750, 14)

# %%
df.wind_direction = df.wind_direction/df.wind_direction.max()

# %%
str(df.date_time[0])
# Out:
# '2012-10-02 09:00:00'

# %%
datetime.strptime(str(df.date_time[0]), '%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2b1ae5130793> in <module>
# ----> 1 datetime.strptime(str(df.date_time[0]), '%Y-%m-%d %H:%M:%S')
#
# NameError: name 'datetime' is not defined

# %%
from datetime import datetime
a = datetime.strptime(str(df.date_time[0]), "%Y-%m-%d %H:%M:%S")
a.month
# Out:
# 10

# %%
from tqdm import tqdm_notebook as tqdm
month = []
for i in tqdm(range(df.shape[0])):
    a = datetime.strptime(str(df.date_time[i]), "%Y-%m-%d %H:%M:%S")
    month.append(a.month)
              
df['month'] = month

# %%
# print(df.traffic_volume[df.month == 6].max())
# print(df.traffic_volume[df.month == 6].min())
# print(df.traffic_volume[df.month == 1].max())
# print(df.traffic_volume[df.month == 1].min())

# %%
df.month[df.temperature == df.temperature.max()]
# Out:
# date_time
# 2013-05-15 17:00:00    5
# Name: month, dtype: int64

# %%
df.traffic_volume[df.month == 5]
# Out:
# date_time
# 2013-05-01 00:00:00     529
# 2013-05-01 02:00:00     283
# 2013-05-01 03:00:00     341
# 2013-05-01 04:00:00     746
# 2013-05-01 05:00:00    2561
# 2013-05-01 06:00:00    5169
# 2013-05-01 07:00:00    6017
# 2013-05-01 08:00:00    5860
# 2013-05-01 09:00:00    5208
# 2013-05-01 10:00:00    4493
# 2013-05-01 11:00:00    4770
# 2013-05-01 12:00:00    4975
# 2013-05-01 13:00:00    4923
# 2013-05-01 14:00:00    5331
# 2013-05-01 15:00:00    5599
# 2013-05-01 16:00:00    6421
# 2013-05-01 17:00:00    6312
# 2013-05-01 18:00:00    4541
# 2013-05-01 19:00:00    3211
# 2013-05-01 20:00:00    2761
# 2013-05-01 21:00:00    2498
# 2013-05-01 22:00:00    1582
# 2013-05-01 23:00:00    1080
# 2013-05-02 00:00:00     544
# 2013-05-02 01:00:00     341
# 2013-05-02 02:00:00     268
# 2013-05-02 03:00:00     304
# 2013-05-02 04:00:00     708
# 2013-05-02 04:00:00     708
# 2013-05-02 05:00:00    2575
#                        ...
# 2017-05-17 10:00:00    4517
# ...

# %%
plt.figure(figsize=(12,12))
plt.plot(df.date_time,df.traffic_volume)

# %%
plt.figure(figsize=(12,7))
ts = df.traffic_volume.head(200)
plt.plot(ts)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
#     rolmean = pd.rolling_mean(timeseries, window=12)
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
#     rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    plt.figure(figsize=(12,7))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print( dfoutput)

# %%
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.773897e+00
# p-value                        2.600020e-09
# #Lags Used                     1.300000e+01
# Number of Observations Used    1.860000e+02
# Critical Value (1%)           -3.466005e+00
# Critical Value (5%)           -2.877208e+00
# Critical Value (10%)          -2.575122e+00
# dtype: float64

# %%
# plt.figure(figsize=(20,8))
# plt.bar(df.month, df.temperature)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-ddc51a0f311a> in <module>
#       1 plt.figure(figsize=(20,8))
# ----> 2 plt.bar(df.month, df.temperature)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)

# %%
x = df.pop('date_time')

# %%
x = df.drop('traffic_volume',1)
y = df['traffic_volume']

# %%
x1 = df.pop('chutti')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chutti'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-93322686adec> in <module>
# ----> 1 x1 = df.pop('chutti')
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.25, random_state=101)

# %%
x_train.columns
# Out:
# Index(['is_holiday', 'air_pollution_index', 'humidity', 'wind_speed',
#        'wind_direction', 'visibility_in_miles', 'dew_point', 'temperature',
#        'rain_p_h', 'snow_p_h', 'clouds_all', 'weather_type', 'month'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
x_train_mm = min_max.fit_transform(x_train[['air_pollution_index', 'humidity', 'wind_speed', 'wind_direction',
       'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h',
       'snow_p_h', 'clouds_all', 'weather_type','month']])

x_test_mm = min_max.fit_transform(x_test[['air_pollution_index', 'humidity', 'wind_speed', 'wind_direction',
       'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h',
       'snow_p_h', 'clouds_all', 'weather_type','month']])

# %%
x_test_mm
# Out:
# array([[0.61245675, 0.33333333, 0.33333333, ..., 0.9       , 0.1       ,
#         0.        ],
#        [0.10726644, 0.71428571, 0.13333333, ..., 0.        , 0.        ,
#         0.45454545],
#        [0.49134948, 0.75      , 0.13333333, ..., 0.01      , 0.6       ,
#         0.63636364],
#        ...,
#        [0.92733564, 0.45238095, 0.2       , ..., 0.4       , 0.1       ,
#         0.18181818],
#        [0.24913495, 0.78571429, 0.33333333, ..., 0.9       , 0.1       ,
#         0.54545455],
#        [0.22145329, 0.82142857, 0.06666667, ..., 0.9       , 0.5       ,
#         0.36363636]])

# %%
# from sklearn.linear_model import LinearRegression
# lr = LinearRegression()
# lr.fit(x_train_mm,y_train)
# pred = lr.predict(x_test_mm)

# %%
# pred = np.log(pred)
# y_test = np.log(y_test)

# y_test_1 = np.nan_to_num(y_test)
# pred1 = np.nan_to_num(pred)

# %%
from sklearn.metrics import mean_squared_error
# mse = mean_squared_error(y_test_1, pred1)

# %%
# mse

# %%
# from sklearn.neighbors import KNeighborsRegressor
# neigh = KNeighborsRegressor(n_neighbors=300)
# neigh.fit(x_train_mm, y_train)
# pred = neigh.predict(x_test_mm)
# # pred = np.log(pred)
# # pred1 = np.nan_to_num(pred)

# # mse = mean_squared_error(y_test, pred)

# %%
# np.log(y_test.min())

# %%
# ch = np.log(pred)

# %%
# np.isnan(ch).any()

# %%
# ch1= np.log(y_test)
# ch1 = ch1.clip(0)
# # ch1 = np.nan_to_num(ch1)
# np.isnan(ch1).any()

# %%
# ch1 = ch1.clip(0)

# %%
# print(ch1.max())
# print(ch1.min())
# print(ch.max())
# print(ch.min())

# %%
# print(ch.max())
# print(ch.min())

# %%
# mse = mean_squared_error(ch, ch1)

# %%
# mse

# %%
# np.isnan(ch1).any()

# %%
# np.isnan(ch1).any()
# ch.max()

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=140)
regressor.fit(x_train_mm, y_train)
pred = regressor.predict(x_test_mm)

ch = np.log(pred)
ch = ch.clip(0)
ch1= np.log(y_test)
ch1 = ch1.clip(0)

mse = mean_squared_error(ch, ch1)
(mse)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
# 1.6494200549200764

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=20, random_state=0, n_estimators=100)
rfr.fit(x_train_mm, y_train)
pred = rfr.predict(x_test_mm)

ch = np.log(pred)
ch = ch.clip(0)
ch1= np.log(y_test)
ch1 = ch1.clip(0)

mse = mean_squared_error(ch, ch1)
(mse)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
# 0.9389736824877633

# %%
from sklearn.linear_model import ElasticNet
en = ElasticNet(random_state = 0)
en.fit(x_train_mm, y_train)
pred = en.predict(x_test_mm)

ch = np.log(pred)
ch = ch.clip(0)
ch1= np.log(y_test)
ch1 = ch1.clip(0)

mse = mean_squared_error(ch, ch1)
(mse)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
# 1.1004179005591321

# %%
from sklearn.ensemble import AdaBoostRegressor
adr = AdaBoostRegressor(random_state = 0, n_estimators = 200)
adr.fit(x_train_mm, y_train)
pred = adr.predict(x_test_mm)

ch = np.log(pred)
ch = ch.clip(0)
ch1= np.log(y_test)
ch1 = ch1.clip(0)

mse = mean_squared_error(ch, ch1)
(mse)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
# 1.0699659548151663

# %%
# import numpy as np
import lightgbm as lgbm
reg = lgbm.sklearn.LGBMRegressor()
reg.fit(x_train_mm, y_train)
pred = reg.predict(x_test_mm)

ch = np.log(pred)
ch = ch.clip(0)
ch1= np.log(y_test)
ch1 = ch1.clip(0)

mse = mean_squared_error(ch, ch1)
(mse)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# 0.9858137932772814

# %% [markdown]
# # Test data preprocessing

# %%
test = pd.read_csv("test.csv")
print(test.shape)
submit = pd.read_csv("sample_submission.csv")
print(submit.shape)
# Out:
# (14454, 14)
# (14454, 2)

# %%
 test
# Out:
#                  date_time is_holiday  air_pollution_index  humidity  \
# 0      2017-05-18 00:00:00       None                   73        63
# 1      2017-05-18 00:00:00       None                  251        63
# 2      2017-05-18 00:00:00       None                   75        56
# 3      2017-05-18 01:00:00       None                   98        56
# 4      2017-05-18 01:00:00       None                  283        56
# 5      2017-05-18 02:00:00       None                  115        49
# 6      2017-05-18 02:00:00       None                   48        49
# 7      2017-05-18 02:00:00       None                  133        49
# 8      2017-05-18 03:00:00       None                  130        60
# 9      2017-05-18 03:00:00       None                   93        60
# 10     2017-05-18 03:00:00       None                  218        60
# 11     2017-05-18 04:00:00       None                  272        75
# 12     2017-05-18 04:00:00       None                  121        75
# ...

# %%
test.date_time.dtype
# Out:
# dtype('O')

# %%
submit.date_time.dtype
# Out:
# dtype('O')

# %%
submit['date_time']= test['date_time']

# %%
submit.shape
# Out:
# (14454, 2)

# %%
arr = test.date_time.unique()

# %%
submit.head()
# Out:
#              date_time  traffic_volume
# 0  2017-05-18 00:00:00           500.0
# 1  2017-05-18 00:00:00           530.0
# 2  2017-05-18 00:00:00           545.0
# 3  2017-05-18 01:00:00           750.0
# 4  2017-05-18 01:00:00             NaN

# %%
len(arr)
# Out:
# 11986

# %%
new_test = test.drop_duplicates(subset='date_time')

# %%
new_test.shape
# Out:
# (11986, 14)

# %%
copy_test = new_test

# %%
test.shape
# Out:
# (14454, 14)

# %%
new_test['date_time'] = pd.to_datetime(new_test['date_time'] ,infer_datetime_format = True)
new_test = new_test.set_index(new_test['date_time'])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
month = []
for i in tqdm(range(new_test.shape[0])):
    a = datetime.strptime(str(new_test.date_time[i]), "%Y-%m-%d %H:%M:%S")
    month.append(a.month)
              
new_test['month'] = month

# %%
# # a = np.array([2012,2013,2014,2015,2016,2017], np.type=int)
# # a=[2012,2013,2014,2015,2016,2017]
# # for j in range(len(a)):    
# #     for i in holidays.US(years = a[j]).items(): 
# from tqdm import tqdm_notebook as tqdm
# chutti = [] 
# for i in tqdm(range(new_test.shape[0])):
# #     df['chutti'][i] = off.get(df.index.date[i])
#     chutti.append(str(off.get(new_test.index.date[i])))

# %%
new_test['chutti'] = chutti
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-31f6794eabab> in <module>
# ----> 1 new_test['chutti'] = chutti
#
# NameError: name 'chutti' is not defined

# %%
submit.head()
submit.shape
# Out:
# (14454, 2)

# %%
# submit['date_time'] = test['date_time']
x = new_test.pop('is_holiday')

# %%
le = LabelEncoder()
new_test.weather_type = le.fit_transform(new_test.weather_type)

# %%
# test.weather_description.value_counts()
x = new_test.pop('weather_description') #since clouds all is too much related to this feature...clouds all is giving the percentage of weather clear

# %%
new_test.clouds_all = new_test.clouds_all/new_test.clouds_all.max() #scaled the clouds_all feature

# %%
chutti_new = []
for i in tqdm(range(new_test.shape[0])):
    if new_test['chutti'][i] == 'None':
        chutti_new.append(0)            
    elif new_test['chutti'][i] == 'Christmas Day (Observed)' or new_test['chutti'][i] =='Independence Day (Observed)' or new_test['chutti'][i] =='New Year\'s Day (Observed)' or new_test['chutti'][i] == 'Veterans Day (Observed)' :
        chutti_new.append(3) 
    elif new_test['chutti'][i] == 'Labor Day' or new_test['chutti'][i] == 'Independence Day'or new_test['chutti'][i] == 'Memorial Day' or new_test['chutti'][i] == "New Year's Day" or new_test['chutti'][i] == 'Christmas Day':
        chutti_new.append(2) 
    else:
        chutti_new.append(1)
        
new_test['chutti'] = chutti_new
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chutti'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-372f1be76a03> in <module>
#       1 chutti_new = []
# ...

# %%
new_test.chutti.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-d06bb149e2ba> in <module>
# ----> 1 new_test.chutti.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'chutti'

# %%
x = new_test.pop("date_time")

# %%
new_test.wind_direction = new_test.wind_direction/new_test.wind_direction.max()

# %%
# plt.figure(figsize=(20,12))
# sns.heatmap(df.corr(),annot=True)

# %%
# from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
x_train_mm = min_max.fit_transform(x_train[['air_pollution_index', 'humidity', 'wind_speed', 'wind_direction',
       'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h',
       'snow_p_h', 'clouds_all', 'weather_type','month']])

x_test_mm = min_max.fit_transform(x_test[['air_pollution_index', 'humidity', 'wind_speed', 'wind_direction',
       'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h',
       'snow_p_h', 'clouds_all', 'weather_type','month']])

# %%
new_test = min_max.fit_transform(new_test[['air_pollution_index', 'humidity', 'wind_speed', 'wind_direction',
       'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h',
       'snow_p_h', 'clouds_all', 'weather_type', 'month']])

# %%
# new_test.head(3)

# %%
x = new_test.pop('chutti')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-c14e245b7336> in <module>
# ----> 1 x = new_test.pop('chutti')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'pop'

# %%
answer = rfr.predict(new_test)
answer
# Out:
# array([2966.015     , 2889.25      , 3081.935     , ..., 2812.57482199,
#        3363.28944444, 2788.01458333])

# %%
test.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00       None                   73        63           1
# 1  2017-05-18 00:00:00       None                  251        63           1
# 2  2017-05-18 00:00:00       None                   75        56           1
# 3  2017-05-18 01:00:00       None                   98        56           1
# 4  2017-05-18 01:00:00       None                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %%
len(answer)
# Out:
# 11986

# %%
# new_test

# %%
copy_test.shape
# Out:
# (11986, 14)

# %%
copy_test["answer1"] = answer
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
copy_test.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00       None                   73        63           1
# 3  2017-05-18 01:00:00       None                   98        56           1
# 5  2017-05-18 02:00:00       None                  115        49           1
# 8  2017-05-18 03:00:00       None                  130        60           2
# 11 2017-05-18 04:00:00       None                  272        75           2
#
#     wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0               27                    4          4       285.15       0.0
# 3              351                    2          2       284.79       0.0
# 5               27                    4          4       284.29       0.0
# 8               36                    6          6       283.51       0.0
# 11              78                    9          9       283.09       0.0
#
# ...

# %%
index_arr = copy_test.index
index_arr
# Out:
# Int64Index([    0,     3,     5,     8,    11,    14,    17,    19,    21,
#                24,
#             ...
#             14442, 14444, 14446, 14447, 14448, 14449, 14450, 14451, 14452,
#             14453],
#            dtype='int64', length=11986)

# %%
# submit.traffic_volume[submit.index[2]]
submit.traffic_volume[submit.index[1]]
# Out:
# 530.0

# %%
for i in tqdm(index_arr):
#     submit.traffic_volume[submit.index[i]] = copy_test.answer1[copy_test.index[i]]
    submit.traffic_volume[i] = copy_test.answer1[i]
# Out:
# ...
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
submit.traffic_volume[1] = submit.traffic_volume[0]
submit.traffic_volume[2] = submit.traffic_volume[0]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
submit
# Out:
#                  date_time  traffic_volume
# 0      2017-05-18 00:00:00     2966.015000
# 1      2017-05-18 00:00:00     2966.015000
# 2      2017-05-18 00:00:00     2966.015000
# 3      2017-05-18 01:00:00     2889.250000
# 4      2017-05-18 01:00:00             NaN
# 5      2017-05-18 02:00:00     3081.935000
# 6      2017-05-18 02:00:00             NaN
# 7      2017-05-18 02:00:00             NaN
# 8      2017-05-18 03:00:00     3052.109364
# 9      2017-05-18 03:00:00             NaN
# 10     2017-05-18 03:00:00             NaN
# 11     2017-05-18 04:00:00     2784.018571
# 12     2017-05-18 04:00:00             NaN
# 13     2017-05-18 04:00:00             NaN
# 14     2017-05-18 05:00:00     3046.685000
# 15     2017-05-18 05:00:00             NaN
# 16     2017-05-18 05:00:00             NaN
# 17     2017-05-18 06:00:00     2707.728571
# 18     2017-05-18 06:00:00             NaN
# 19     2017-05-18 07:00:00     2591.294926
# 20     2017-05-18 07:00:00             NaN
# ...

# %%
submit.isnull().sum()
# Out:
# date_time            0
# traffic_volume    2466
# dtype: int64

# %%
submit = submit.fillna(method = 'ffill')

# %%
# copy_test = copy_test.reset_index(drop=True)

# %%
copy_test
# Out:
#                 date_time is_holiday  air_pollution_index  humidity  \
# 0     2017-05-18 00:00:00       None                   73        63
# 3     2017-05-18 01:00:00       None                   98        56
# 5     2017-05-18 02:00:00       None                  115        49
# 8     2017-05-18 03:00:00       None                  130        60
# 11    2017-05-18 04:00:00       None                  272        75
# 14    2017-05-18 05:00:00       None                  231        84
# 17    2017-05-18 06:00:00       None                   85        84
# 19    2017-05-18 07:00:00       None                  165        67
# 21    2017-05-18 08:00:00       None                  247        67
# 24    2017-05-18 09:00:00       None                  102        51
# 27    2017-05-18 10:00:00       None                  122        47
# 29    2017-05-18 11:00:00       None                  181        45
# 30    2017-05-18 12:00:00       None                   71        45
# ...

# %%
type(submit["date_time"][0])
# Out:
# str

# %%
# str(copy_test["date_time"][3]) == submit["date_time"][1]

# %%
# submit["traffic_volume"] = copy_test.answer1[submit.date_time == copy_test.date_time]

# %%
# #====>> time complexity improved
# #--------------------------------

# j = 0
# c=1
# ch = 0
# for i in tqdm(range(copy_test.shape[0])):   
#     while (c==1):
#         if str(copy_test["date_time"][i]) == submit["date_time"][j]:
#             submit["traffic_volume"][j] = copy_test["answer1"][i]
#             j += 1
#             ch += 1
#             if str(copy_test["date_time"][i]) != submit["date_time"][j+1]:
#                 c=0
#                 j=j-1
                    
# ch

# %%
submit.isnull().sum()
# Out:
# date_time         0
# traffic_volume    0
# dtype: int64

# %%
submit.traffic_volume = np.round(submit.traffic_volume)

# %%
# # ====>> time complexity high
# # --------------------------------


# for j in tqdm(range(copy_test.shape[0])):
#     for i in range(submit.shape[0]):
#         if str(copy_test["date_time"][j]) == submit["date_time"][i]: 
#             submit["traffic_volume"][i] = copy_test["answer1"][j]
#             print(submit["traffic_volume"][i])
#             break

# %%
# submit['traffic_volume'] = answer

# %%
submit.to_csv("answer1.csv",index=False)

# %%
submit
# Out:
#                  date_time  traffic_volume
# 0      2017-05-18 00:00:00          2966.0
# 1      2017-05-18 00:00:00          2966.0
# 2      2017-05-18 00:00:00          2966.0
# 3      2017-05-18 01:00:00          2889.0
# 4      2017-05-18 01:00:00          2889.0
# 5      2017-05-18 02:00:00          3082.0
# 6      2017-05-18 02:00:00          3082.0
# 7      2017-05-18 02:00:00          3082.0
# 8      2017-05-18 03:00:00          3052.0
# 9      2017-05-18 03:00:00          3052.0
# 10     2017-05-18 03:00:00          3052.0
# 11     2017-05-18 04:00:00          2784.0
# 12     2017-05-18 04:00:00          2784.0
# 13     2017-05-18 04:00:00          2784.0
# 14     2017-05-18 05:00:00          3047.0
# 15     2017-05-18 05:00:00          3047.0
# 16     2017-05-18 05:00:00          3047.0
# 17     2017-05-18 06:00:00          2708.0
# 18     2017-05-18 06:00:00          2708.0
# 19     2017-05-18 07:00:00          2591.0
# 20     2017-05-18 07:00:00          2591.0
# ...

# %%
copy_test.answer1[copy_test.date_time == '2018-09-30 13:00:00']
# Out:
# 14441    3075.049167
# Name: answer1, dtype: float64
